# %%
from bs4 import BeautifulSoup as soup
import pandas as pd
import requests
import re,string
from nltk.corpus import stopwords
import logging
import pickle 
import time
import random
import datetime

# %%
logging.basicConfig(level=logging.INFO)
logging.getLogger("requests").setLevel(logging.WARNING)
logging.getLogger("urllib3").setLevel(logging.WARNING)

LOG = {}
def logger(func):
        def wrapper(*args, **kwargs):
            try:        
                res = func(*args, **kwargs)          
                LOG["{}".format(func.__name__)] = res
                return res
            except Exception as e:
                logging.exception(e)
        return wrapper
    

def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
URL = 'https://finviz.com/news.ashx'
HEADERS = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

@logger
def get_page(url):
    content = requests.get(url, headers=HEADERS).text
    parsed = soup(content, 'html.parser')
    parsed_news_block = parsed.findAll("tr", {"class": "nn"})
    return parsed_news_block

page = get_page(URL)

# %%
@logger
def parse_finviz_page(page):
    news_titles = []
    news_links = []
    for news_item in page:
        news_titles.append(news_item.findAll('a')[0].contents)
        news_links.append(news_item.findAll('a', href = True)[0]['href'])
    return news_titles, news_links
             

titles, links = parse_finviz_page(page)

# %%
@logger
def to_df(titles,links):
    date_str = str(datetime.datetime.now().date())
    df = pd.DataFrame(list(zip(titles,links)))
    date_to_add = [date_str]*len(df)
    df['date'] = date_to_add
    return df

@logger
def write_to_csv(df, news_vocab = None):
    date_str = str(datetime.datetime.now().date())
    if news_vocab:
        df.to_csv(f'news_vocab/{date_str}.csv')
    else:
        df.to_csv(f'{date_str}.csv')
    return None

# %%
def scrape(url):
    df = to_df(*parse_finviz_page(get_page(url)))
    write_to_csv(df)
    return df
    
scrape(URL)
# Out:
#                                                      0  \
# 0    [Chilean central bank strikes deal with China ...
# 1    [Gold Climbs to All-Time High, Topping 2011 Re...
# 2    [The Tech-Backed Institute That Shapes How Gov...
# 3    [Chilean health minister announces gradual lif...
# 4    [UPDATE 1-German COVID-19 vaccine developer Cu...
# ..                                                 ...
# 175                  [A Few Big Ideas For The Weekend]
# 176                                 [Some Good Reads…]
# 177                [Russell 2000 Readies For Breakout]
# 178               [Americans Are Getting Out of Dodge]
# 179                    [Brown Weeds, Not Green Shoots]
#
#                                                      1        date
# 0    https://www.reuters.com/article/chile-economy/...  2020-07-24
# 1    https://www.wsj.com/articles/gold-climbs-to-al...  2020-07-24
# 2    https://www.nytimes.com/2020/07/24/technology/...  2020-07-24
# 3    https://www.reuters.com/article/health-coronav...  2020-07-24
# 4    https://www.reuters.com/article/curevac-ipo/up...  2020-07-24
# ..                                                 ...         ...
# 175  http://traderfeed.blogspot.com/2020/07/a-few-b...  2020-07-24
# 176       https://howardlindzon.com/some-good-reads-2/  2020-07-24
# 177  http://feedproxy.google.com/~r/FallondStockPic...  2020-07-24
# 178  http://feedproxy.google.com/~r/dailyreckoning/...  2020-07-24
# 179  http://feedproxy.google.com/~r/dailyreckoning/...  2020-07-24
#
# [180 rows x 3 columns]

# %%
def read(fp = None):
    if fp:
         df = pd.read_csv(fp)
    date_str = str(datetime.datetime.now().date())
    return pd.read_csv(f'{date_str}.csv')

# %%
df = read()
df
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  ["Trump says pandemic will probably 'get worse...
# 1             1  ['Stocks making the biggest moves after hours:...
# 2             2  ['UPDATE 2-United warns travel demand will lan...
# 3             3  ['Hertz inks temporary deal with creditors lin...
# 4             4  ['E-brokers TD Ameritrade, Interactive Brokers...
# ..          ...                                                ...
# 175         175                 ['DHUnplugged #514: To The Moon!']
# 176         176                 ['S&P Breakout Wait Continues...']
# 177         177  ['Cultural Marxism and TraCultural Marxism and...
# 178         178            ['Investing is Hard …and Tesla Topped']
# 179         179                                      ['Inflation']
#
#                                                      1        date
# 0    https://edition.cnn.com/world/live-news/corona...  2020-07-21
# 1    https://www.cnbc.com/2020/07/21/stocks-making-...  2020-07-21
# 2    https://www.reuters.com/article/united-arlns-r...  2020-07-21
# 3    http://feeds.marketwatch.com/~r/marketwatch/ma...  2020-07-21
# 4    https://www.cnbc.com/2020/07/21/e-brokers-td-a...  2020-07-21
# ..                                                 ...         ...
# 175  http://feedproxy.google.com/~r/thedisciplinedi...  2020-07-21
# 176  http://feedproxy.google.com/~r/FallondStockPic...  2020-07-21
# 177  http://feedproxy.google.com/~r/dailyreckoning/...  2020-07-21
# 178  https://howardlindzon.com/investing-is-hard-an...  2020-07-21
# 179  http://feedproxy.google.com/~r/dailyreckoning/...  2020-07-21
#
# [180 rows x 4 columns]

# %%
def parse_news_article(link):
    content = requests.get(link, headers=headers).content
    parsed = soup(content, 'html.parser')
    return parsed.get_text(' ')

z = parse_news_article(df.iloc[:,3][1])
# Out:
# 2020-07-21 20:51:48,244 - chardet.charsetprober - DEBUG - get_confidence - utf-8  confidence = 0.99
# 2020-07-21 20:51:48,245 - chardet.charsetprober - DEBUG - get_confidence - SHIFT_JIS Japanese confidence = 0.01
# 2020-07-21 20:51:48,245 - chardet.charsetprober - DEBUG - get_confidence - EUC-JP Japanese confidence = 0.01
# 2020-07-21 20:51:48,246 - chardet.charsetprober - DEBUG - get_confidence - GB2312 Chinese confidence = 0.01
# 2020-07-21 20:51:48,247 - chardet.charsetprober - DEBUG - get_confidence - EUC-KR Korean confidence = 0.01
# 2020-07-21 20:51:48,249 - chardet.charsetprober - DEBUG - get_confidence - CP949 Korean confidence = 0.01
# 2020-07-21 20:51:48,249 - chardet.charsetprober - DEBUG - get_confidence - Big5 Chinese confidence = 0.01
# 2020-07-21 20:51:48,250 - chardet.charsetprober - DEBUG - get_confidence - EUC-TW Taiwan confidence = 0.01
# 2020-07-21 20:51:48,251 - chardet.charsetprober - DEBUG - get_confidence - windows-1251 Russian confidence = 0.01
# 2020-07-21 20:51:48,252 - chardet.charsetprober - DEBUG - get_confidence - KOI8-R Russian confidence = 0.01
# 2020-07-21 20:51:48,252 - chardet.charsetprober - DEBUG - get_confidence - ISO-8859-5 Russian confidence = 0.01
# 2020-07-21 20:51:48,253 - chardet.charsetprober - DEBUG - get_confidence - MacCyrillic Russian confidence = 0.0
# 2020-07-21 20:51:48,253 - chardet.charsetprober - DEBUG - get_confidence - IBM866 Russian confidence = 0.09833159072491911
# 2020-07-21 20:51:48,254 - chardet.charsetprober - DEBUG - get_confidence - IBM855 Russian confidence = 0.0
# 2020-07-21 20:51:48,255 - chardet.charsetprober - DEBUG - get_confidence - ISO-8859-7 Greek confidence = 0.0
# 2020-07-21 20:51:48,255 - chardet.charsetprober - DEBUG - get_confidence - windows-1253 Greek confidence = 0.0
# 2020-07-21 20:51:48,256 - chardet.charsetprober - DEBUG - get_confidence - ISO-8859-5 Bulgairan confidence = 0.01
# 2020-07-21 20:51:48,257 - chardet.charsetprober - DEBUG - get_confidence - windows-1251 Bulgarian confidence = 0.01
# 2020-07-21 20:51:48,257 - chardet.charsetprober - DEBUG - get_confidence - TIS-620 Thai confidence = 0.0
# 2020-07-21 20:51:48,258 - chardet.charsetprober - DEBUG - get_confidence - ISO-8859-9 Turkish confidence = 0.4958353606413677
# 2020-07-21 20:51:48,258 - chardet.charsetprober - DEBUG - get_confidence - windows-1255 Hebrew confidence = 0.0
# 2020-07-21 20:51:48,259 - chardet.charsetprober - DEBUG - get_confidence - windows-1255 Hebrew confidence = 0.0
# 2020-07-21 20:51:48,259 - chardet.charsetprober - DEBUG - get_confidence - windows-1255 Hebrew confidence = 0.0
# 2020-07-21 20:51:48,260 - chardet.charsetprober - DEBUG - get_confidence - utf-8  confidence = 0.99
# 2020-07-21 20:51:48,261 - chardet.charsetprober - DEBUG - get_confidence - SHIFT_JIS Japanese confidence = 0.01
# 2020-07-21 20:51:48,261 - chardet.charsetprober - DEBUG - get_confidence - EUC-JP Japanese confidence = 0.01
# 2020-07-21 20:51:48,262 - chardet.charsetprober - DEBUG - get_confidence - GB2312 Chinese confidence = 0.01
# 2020-07-21 20:51:48,263 - chardet.charsetprober - DEBUG - get_confidence - EUC-KR Korean confidence = 0.01
# 2020-07-21 20:51:48,264 - chardet.charsetprober - DEBUG - get_confidence - CP949 Korean confidence = 0.01
# 2020-07-21 20:51:48,264 - chardet.charsetprober - DEBUG - get_confidence - Big5 Chinese confidence = 0.01
# 2020-07-21 20:51:48,265 - chardet.charsetprober - DEBUG - get_confidence - EUC-TW Taiwan confidence = 0.01

# %%
z
# Out:
# "Stocks making the biggest moves after hours: Snap, United Airlines, Capital One and more × LOG IN SIGN UP Keep Me Logged In Skip Navigation SIGN IN Pro Watchlist Make It Select USA INTL Markets Pre-Markets U.S. Markets Currencies Cryptocurrency Futures & Commodities Bonds Funds & ETFs Watchlist Business Economy Finance Health & Science Media Real Estate Energy Transportation Industrials Retail Wealth Life Small Business Investing Invest In You Personal Finance Financial Advisors Trading Nation Options Action ETF Street Buffett Archive Earnings Trader Talk Tech Cybersecurity Enterprise Internet Media Mobile Social Media Venture Capital Tech Guide Politics White House Policy Defense Congress 2020 Elections CNBC TV Live TV Live Audio Latest Video Top Video CEO Interviews Business Day Shows Primetime Shows CNBC World Digital Originals Full Episodes Menu SEARCH QUOTES Markets Pre-Markets U.S. Markets Currencies Cryptocurrency Futures & Commodities Bonds Funds & ETFs Watchlist Business Economy Finance Health & Science Media Real Estate Energy Transportation Industrials Retail Wealth Life Small Business Investing Invest In You Personal Finance Financial Advisors Trading Nation Options Action ETF Street Buffett Archive Earnings Trader Talk Tech Cybersecurity Enterprise Internet Media Mobile Social Media Venture Capital Tech Guide Politics White House Policy Defense Congress 2020 Elections CNBC TV Live TV Live Audio Latest Video Top Video CEO Interviews Business Day Shows Primetime Shows CNBC World Digital Originals Full Episodes Menu Market Insider Stocks making the biggest moves after hours: Snap, United Airlines, Capital One and more Published Tue, Jul 21 2020 5:38 PM EDT Updated 25 Min Ago Michelle Gao @michgao Suzanne Blake @thesuzanneblake VIDEO 13:16 13:16 How Taiwan beat the coronavirus: CNBC After Hours CNBC After Hours Check out the companies making headlines after the bell :\xa0 Snap \xa0—\xa0The social media company's stock fell 5% in extended trading after itreleased its\xa0 second-quarter financial results . The company reported a loss of 9 cents per share, in line with Refinitiv analysts' estimate, and revenues of $454 million, compared to analysts' estimate of $439.1 million. Snap's net loss also grew nearly 28% to $326 million from $255 million last year.\xa0 Capital One \xa0— Shares of Capital One fell 4% in after hours upon releasing  second quarter financial results. \xa0Capitol One reported a net loss of $1.61 per share excluding some items. The company's total net revenue decreased 10% to $6.6 billion. United Airlines  — Shares of United Airlines rose 1.5% in extended trading after the company released its\xa0 second-quarter financial results . United posted a loss of $9.31 per share on revenues of $1.48 billion, compared to Refinitiv analysts' estimate of a $9.02 loss per share on revenues of $1.32 billion. The airline also said it expects its daily cash burn to decrease to $25 million next quarter from an average of $40 million per day in the second quarter. Inovio \xa0— Shares of Inovio dropped 1% in extended trading after rising 6.6% in regular hours. Drug company executives from\xa0 AstraZeneca ,\xa0 Johnson & Johnson ,\xa0 Merck ,\xa0 Moderna \xa0and\xa0 Pfizer \xa0told Congress earlier Tuesday  they are not lowering their standards in the race to develop a coronavirus vaccine , which they said they should be able to produce by early 2021. FirstEnergy \xa0— FirstEnergy's stock fell 2% after the closing bell after plummeting 16.99% earlier in the day. The company received subpoenas in connection with the investigation surround Ohio House Bill 6. Ohio House Speaker Larry Householder has been arrested regarding a $60 million federal racketeering case over the state's new nuclear bailout law,  according to SeekingAlpha. \xa0 Texas Instruments \xa0— Texas Instruments' stock climbed 1% in extended trading after the company's  second quarter financial results  beat Refinitiv analysts' revenue estimates. Texas Inst ...

# %%
    
def clean_doc(doc): 
    #split document into individual words
    tokens=doc.split()
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 4]
    #lowercase all words
    tokens = [word.lower() for word in tokens]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]         
    # word stemming    
    # ps=PorterStemmer()
    # tokens=[ps.stem(word) for word in tokens]
    return tokens

# %%
def iterate_over_links(df, req_limit = 1000):
    vocab = {}
    for i, news_link in enumerate(df.iloc[:,2]):
        if i > req_limit:
            break
        try:
            vocab[i] = clean_doc(parse_news_article(news_link)) 
            print("Successfully added: {}".format(df.iloc[i,1]))
        except Exception as e:
            r = random.randint(2,7)
            time.sleep(r)
            vocab[i] = '#NA'
            print(e)
    return vocab

# %%
def get_vocab(df):
    if 
    vocabulary = iterate_over_links(df)
    df['vocab'] = list(vocabulary.values())
    date_str = str(datetime.datetime.now().date())
    save_obj(df, date_str)
    return df

# %%
# Out:
# Successfully added: ["Trump says pandemic will probably 'get worse before it gets better'"]
# Successfully added: ['Stocks making the biggest moves after hours: Snap, United Airlines, Capital One and more']
# Successfully added: ['UPDATE 2-United warns travel demand will languish until COVID-19 vaccine']
# Successfully added: ['Hertz inks temporary deal with creditors linked to fleet-reduction plan']
# Successfully added: ['E-brokers TD Ameritrade, Interactive Brokers sustained record retail trading volumes in the second quarter']
# Successfully added: ['Insurers lobby for federal pandemic insurance program']
# Successfully added: ['Mexico central bank likely to cut key rate 50 bp in August -Citibanamex survey']
# Successfully added: ['UPDATE 1-S&P 500 turns positive for 2020, but most stocks are missing the party']
# Successfully added: ['Teradyne stock rises as earnings, outlook top Street view']
# Successfully added: ['Pharma execs deny cutting corners in vaccine development, praise FDA for not lowering standards']
# Successfully added: ['Tesla stock options are priced for an unusually big post-earnings move — but odds are stacked against bettors']
# Successfully added: ['UPDATE 5-Next U.S. coronavirus bill to include more money for unemployed, spending -lawmakers']
# Successfully added: ["UPDATE 3-Argentina's $65 bln debt deal inches closer despite standoff"]
# Successfully added: ['All Markets Summit Extra: CEOs offer clarity amid crisis']
# Successfully added: ['China Fuel Flood Has Asia Gasoline Recovery From Virus Teetering']
# Successfully added: ['Macau Casinos Likely to Post $1 Billion Loss in June Quarter']
# Successfully added: ['UPDATE 1-Brazil tax proposal centers on new 12% VAT levy on goods, services']
# Successfully added: ['API data show a climb of more than 7 million barrels in U.S. crude supplies, sources say']
# Successfully added: ['UPDATE 1-United improves quarterly cash burn but employee demand for early exits weak']
# Successfully added: ['Gold, silver prices surge to highest levels in years']
# Successfully added: ['Best Buy online sales jump as shoppers snap up computers, appliances']
# Successfully added: ['Pandemic Luxury: ‘Concierge-Style’ Coaches and $350 Movie Tickets']
# Successfully added: ["GLOBAL MARKETS-Stocks, euro rally on EU's massive recovery fund"]
# Successfully added: ['United Airlines improves cash burn after matching flying to demand']
# Successfully added: ['CANADA FX DEBT-C$ climbs to 5-week high vs U.S. dollar as oil prices rise']
# Successfully added: ["Here's what happened to the stock market on Tuesday"]
# Successfully added: ['Fast-Food Brand Arby’s Dabbles in Obscure Segment of Bond Market']
# Successfully added: ["Fauci says he wasn't invited to Trump's coronavirus briefing today"]
# Successfully added: ['Arlo stock gains 27% after company strikes security partnership']
# Successfully added: ['Canada legislators approve proposal to expand emergency wage subsidy program']
# Successfully added: ['Texas Instruments stock rises on earnings, outlook beat']
# Successfully added: ['S&P 500 closes slightly higher as stimulus hopes lift cyclical stocks']
# Successfully added: ['Stocks Eke Out Gain Amid Doubt on Stimulus Timing: Markets Wrap']
# Successfully added: ['Stocks limp into the close as fiscal stimulus efforts flail']
# Successfully added: ['Dow Industrials End Higher as Investors Look to Earnings']
# Successfully added: ['US STOCKS-S&P 500 closes slightly higher as stimulus hopes lift cyclical stocks']
# Successfully added: ['Xi’s Radical Stock Market Reforms Shield China Firms From U.S']
# Successfully added: ['A Quirk of Japan’s Credit Market Is Hurting Some New Debt Sales']
# Successfully added: ['Lockheed Martin boost sales forecast as Pentagon amps up contract awards']
# Successfully added: ['S&P 500 turns positive for 2020, but most stocks are missing the party']
# Successfully added: ['FOREX-EU virus deal sends Euro to 1-1/2 year high vs dollar']
# Successfully added: ["UPDATE 2-Senate panel narrowly approves Trump's Fed nominee Shelton"]
# Successfully added: ['TREASURIES-Yields dip as economic stimulus talks intensify']
# Successfully added: ["Tesla's Musk qualifies for $2.1 billion payday"]
# Successfully added: ['GLOBAL MARKETS-Stocks, euro rally after EU agrees to recovery fund']
# Successfully added: ["UPDATE 2-Argentina's $65 bln debt deal inches closer despite standoff"]
# Successfully added: ['Santander Chairman says EU aid agreement paves way for cross-border mergers']
# Successfully added: ['Wells Fargo appoints Mike Santomassimo CFO']
# Successfully added: ["EMERGING MARKETS-Commodity-linked Latam FX gain; Brazil's real at 1-month high"]
# Successfully added: ["UPDATE 1-Senate panel narrowly approves Trump's Fed nominee Shelton"]
# Successfully added: ['UPDATE 2-Lebanon to hire Alvarez & Marsal to audit central bank amid crisis']
# Successfully added: ["Oil futures settle higher, buoyed by the European Union's stimulus package"]
# Successfully added: ['Threat to Dollar’s Global Supremacy Revived by EU Stimulus Deal']
# Successfully added: ['ANALYSIS-EU fund seen as turning point for eurozone financial assets']
# Successfully added: ["Senate panel approves Trump's Fed nominee Shelton"]
# Successfully added: ['Key Senate committee approves Shelton, Waller for Fed positions']
# Successfully added: ['US STOCKS-Wall Street gains as investors bet on stimulus']
# Successfully added: ['MEDIA-UK audit regulator asks companies for more details on COVID-19 impact - WSJ']
# Successfully added: ['UPDATE 1-Santander Brasil launches $964 mln credit line for sanitation']
# Successfully added: ['How to invest in the US real estate boom']
# Successfully added: ['Canadian Pacific raises quarterly dividend by 14.5%']
# Successfully added: ['Santander Brasil launches 5 bln reais credit line for sanitation']
# Successfully added: ["US charges Chinese hackers over 'sweeping' intrusions including Covid-19 research"]
# Successfully added: ['Scientists are one step closer to delaying aging']
# Successfully added: ['Philip Morris sales weaken after coronavirus disrupts production']
# Successfully added: ["Tesla could soon join the S&P 500 — but inclusion isn't automatic, even with a full year of profitability"]
# Successfully added: ['US STOCKS-S&P 500, Dow rise after positive earnings, stimulus bets']
# Successfully added: ["Profit or not? Analysts divided ahead of Tesla's second-quarter results"]
# Successfully added: ['Robinhood Cancels U.K. Launch Amid U.S. Outages, Controversy']
# Successfully added: ['Brazil real estate firm Nortis seeks to register IPO']
# Successfully added: ['That extra $600 unemployment benefit may end sooner than many think']
# Successfully added: ["UPDATE 1-'Inching closer': Argentina's debt deal hopes rise despite standoff"]
# Successfully added: ['Prosecutor Seeks 8 Years Jail for Eni CEO on Bribe Charge']
# Successfully added: ['FOREX-Euro hits 1-1/2 year high vs dollar after EU virus deal']
# Successfully added: ['OPKO Health Unit to Expand Pro-Sports Covid Testing to NFL']
# Successfully added: ['Microsoft, Nike, Unilever team up to combat global carbon emissions']
# Successfully added: ['UPDATE 2-UK midcaps close at 2-week high; Bluechips stifled by healthcare, miners']
# Successfully added: ['UPDATE 2-Bullish markets lift pound to 6-week high, look past economy woes']
# Successfully added: ['U.K. Private Sector Job Support Rises to £37.6 Billion']
# Successfully added: ['UPDATE 3-European stocks hit over 4-month highs after EU recovery fund sealed']
# Successfully added: ['Stocks making the biggest moves midday: IBM, Coca-Cola, Wells Fargo, Devon Energy and more']
# Successfully added: ['GLOBAL MARKETS-Stocks, euro rally after EU agrees to  recovery fund']
# Successfully added: ['Euro Rises to 18-Month High After EU Clinches Rescue Deal']
# Successfully added: ['Forget the Rhetoric, Argentine Talks May Be Too Close to Fail']
# Successfully added: ['ANALYSIS-Ambiguous conditions on EU deal set to embolden Hungary and Poland']
# Successfully added: ['US STOCKS-S&P 500, Dow rise on optimism over earnings reports, stimulus']
# Successfully added: ['Russian lawmakers back plan for retail investments in foreign shares']
